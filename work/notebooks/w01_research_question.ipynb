# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/133Haseeb/MLflyrankhaseeb/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Refresh / Content Opportunity Scoring
#
# I selected Refresh / Content Opportunity Scoring because the starter notebooks focus on identifying pages that should be refreshed. This lane helps prioritize content updates using real search performance data & machine learning.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question:
# How can machine learning identify website pages that should be refreshed first to improve SEO performance?
#
# Decision:
# Decide which content pages should be reviewed & updated first.
#
# Action:
# Review & update the highest-ranked pages before lower-priority pages.
#
# Cost of a wrong recommendation:
# If the model incorrectly prioritizes pages, important declining pages may not be updated in time, resulting in traffic loss and wasted effort.
#
# Why ML helps:
# Machine learning can analyze multiple factors such as impressions, CTR, content age, and ranking position together, making better prioritization than simple hand-written rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess

REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

print("Starter repository is ready.")
# Out:
# Starter repository is ready.

# %% [markdown]
# I loaded the starter dataset and observed the following:
#
# The dataset contains 30,000 rows and 44 columns.
# 16,262 pages are labeled as "down", making declining content the largest category.
# The average CTR is 0.5107.
# The average impressions are 5,200.37.
#
# These numbers suggest that many pages experience declining performance, making Refresh / Content Opportunity Scoring a useful lane. A model that identifies which pages should be refreshed first could help prioritize work and improve content performance.

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv")

print("Total Rows:", len(df))
print("Total Columns:", len(df.columns))

print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())

print("\nAverage CTR:", round(df["ctr"].mean(), 4))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Total Rows: 30000
# Total Columns: 44
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average CTR: 0.5107
# Average Impressions: 5200.37

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis is based on the starter dataset and shows patterns rather than proving cause and effect. The model will provide recommendations, but final decisions should still be reviewed by humans.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [checked ] Every section above is filled — markdown thinking AND the code that backs it
# - [checked] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [checked] No client names, URLs, or private queries anywhere
# - [checked ] My claims use careful words: observed, measured, directional, decision-support
# - [checked ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
